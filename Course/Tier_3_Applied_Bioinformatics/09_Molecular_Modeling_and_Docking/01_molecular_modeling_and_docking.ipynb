# %% [markdown]
# # Molecular Modeling + Docking: Overview
#
# This overview links to separate, self-contained notebooks for each topic.
#
# 1. [Molecular Modeling](./01_molecular_modeling.ipynb)
# 2. [Docking](./02_docking.ipynb)
#
# **Navigation:** [Back to tier](../README.md) · [Open Molecular Modeling](./01_molecular_modeling.ipynb)
