# %% [markdown]
# # Proteomics + Structural Methods: Overview
#
# This overview links to separate, self-contained notebooks for each topic.
#
# 1. [Proteomics](./01_proteomics.ipynb)
# 2. [Structural Methods](./02_structural_methods.ipynb)
#
# **Navigation:** [Back to tier](../README.md) · [Open Proteomics](./01_proteomics.ipynb)

# %% [markdown]
# ---[< Previous: Proteomics](01_proteomics.ipynb) | [Tier 3: Applied Bioinformatics Overview](../README.md) | [Next: Structural Methods >](02_structural_methods.ipynb)---

# %% [markdown]
# ---[< Previous: Proteomics](01_proteomics.ipynb) | [Tier 3: Applied Bioinformatics Overview](../README.md) | [Next: Structural Methods >](02_structural_methods.ipynb)---
