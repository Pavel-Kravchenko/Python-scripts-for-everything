# %% [markdown]
# # 🧬 Python for Bioinformatics
# ## Master Course Index
#
# Welcome to the comprehensive Python for Bioinformatics course! This curriculum takes you from computational basics to advanced bioinformatics analysis.
#
# ---
#
# ## 🎯 How to Use This Course
#
# ### For Beginners
# Start at **Tier 0** and work through sequentially. Each tier builds on the previous.
#
# ### For Those with Python Experience
# Take the **Skills Check** at the start of each tier to test if you can skip ahead.
#
# ### For Experienced Bioinformaticians
# Jump directly to **Tier 2** or **Tier 3** based on your interests.
#
# ---

# %% [markdown]
# ## 🏗️ Course Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────────────┐
# │                    LEARNING PATHWAY                              │
# ├─────────────────────────────────────────────────────────────────┤
# │                                                                  │
# │  ┌──────────────────┐                                           │
# │  │   TIER 0         │  Prerequisites                            │
# │  │   Foundations    │  Linux, Git, Bash, R basics               │
# │  └────────┬─────────┘                                           │
# │           │                                                      │
# │           ▼                                                      │
# │  ┌──────────────────┐                                           │
# │  │   TIER 1         │  Core Programming                         │
# │  │   Python         │  Variables → OOP → Data Analysis          │
# │  └────────┬─────────┘                                           │
# │           │                                                      │
# │           ▼                                                      │
# │  ┌──────────────────┐                                           │
# │  │   TIER 2         │  Bioinformatics Fundamentals              │
# │  │   Core Bio       │  BioPython, Alignment, BLAST, Structure   │
# │  └────────┬─────────┘                                           │
# │           │                                                      │
# │           ▼                                                      │
# │  ┌──────────────────┐                                           │
# │  │   TIER 3         │  Advanced Applications                    │
# │  │   Applied Bio    │  NGS, RNA-seq, ML, Clinical Genomics      │
# │  └──────────────────┘                                           │
# │                                                                  │
# └─────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ---
#
# ## 📚 Tier 0: Computational Foundations
# *Prerequisites for computational biology - skip if experienced*
#
# | # | Topic | Description | Notebook |
# |---|-------|-------------|----------|
# | 0 | **Skills Check** | Test your readiness | [00_skills_check.ipynb](Tier_0_Computational_Foundations/00_Skills_Check/00_skills_check.ipynb) |
# | 1 | **Linux Basics** | Command line navigation, file operations | [01_linux_fundamentals.ipynb](Tier_0_Computational_Foundations/01_Linux_Basics/01_linux_fundamentals.ipynb) |
# | 2 | **Git Version Control** | Tracking changes, collaboration | [01_git_version_control.ipynb](Tier_0_Computational_Foundations/02_Git_Version_Control/01_git_version_control.ipynb) |
# | 3 | **Bash Scripting** | Automation, pipelines | [01_bash_scripting.ipynb](Tier_0_Computational_Foundations/03_Bash_Scripting/01_bash_scripting.ipynb) |
# | 4 | **File Encodings** | UTF-8, ASCII, binary files | [01_character_encodings.ipynb](Tier_0_Computational_Foundations/04_File_Encodings/01_character_encodings.ipynb) |
# | 5 | **R Basics** | Statistical computing intro | [01_r_fundamentals.ipynb](Tier_0_Computational_Foundations/05_R_Basics/01_r_fundamentals.ipynb) |
# | 6 | **Biostatistics** | Hypothesis testing, distributions | [01_biostatistics_fundamentals.ipynb](Tier_0_Computational_Foundations/06_Biostatistics/01_biostatistics_fundamentals.ipynb) |
#
# **🎓 After Tier 0:** You can navigate the command line, use Git, and understand basic statistics.

# %% [markdown]
# ---
#
# ## 🐍 Tier 1: Python for Bioinformatics
# *Core Python programming with biological examples*
#
# ### Part A: Python Fundamentals
#
# | # | Topic | Description | Key Skills |
# |---|-------|-------------|------------|
# | 0 | **Skills Check** | Test your Python knowledge | [00_skills_check.ipynb](Tier_1_Python_for_Bioinformatics/00_Skills_Check/00_skills_check.ipynb) |
# | 1 | **Python Introduction** | Setup, REPL, first programs | [01_python_introduction.ipynb](Tier_1_Python_for_Bioinformatics/01_Python_Introduction/01_python_introduction.ipynb) |
# | 2 | **Variables & Data Types** | Numbers, strings, booleans | [01_variables_and_data_types.ipynb](Tier_1_Python_for_Bioinformatics/02_Variables_and_Data_Types/01_variables_and_data_types.ipynb) |
# | 3 | **Operators & Expressions** | Math, comparison, logic | [01_operators_and_expressions.ipynb](Tier_1_Python_for_Bioinformatics/03_Operators_and_Expressions/01_operators_and_expressions.ipynb) |
# | 4 | **Strings & Sequences** | DNA as strings, slicing | [01_strings_and_sequences.ipynb](Tier_1_Python_for_Bioinformatics/04_Strings_and_Sequences/01_strings_and_sequences.ipynb) |
# | 5 | **Control Flow** | if/else, loops, iteration | [01_control_flow.ipynb](Tier_1_Python_for_Bioinformatics/05_Control_Flow/01_control_flow.ipynb) |
# | 6 | **Functions** | Modular code, reusability | [01_functions.ipynb](Tier_1_Python_for_Bioinformatics/06_Functions/01_functions.ipynb) |
# | 7 | **File Operations** | FASTA, CSV, JSON parsing | [01_file_operations.ipynb](Tier_1_Python_for_Bioinformatics/07_File_Operations/01_file_operations.ipynb) |
#
# ### Part B: Data Structures
#
# | # | Topic | Description | Key Skills |
# |---|-------|-------------|------------|
# | 8 | **Lists & Tuples** | Sequence collections | [01_lists_and_tuples.ipynb](Tier_1_Python_for_Bioinformatics/08_Lists_and_Tuples/01_lists_and_tuples.ipynb) |
# | 9 | **Dictionaries & Sets** | Codon tables, unique k-mers | [01_dictionaries_and_sets.ipynb](Tier_1_Python_for_Bioinformatics/09_Dictionaries_and_Sets/01_dictionaries_and_sets.ipynb) |
# | 10 | **Comprehensions** | Pythonic data transformation | [01_comprehensions.ipynb](Tier_1_Python_for_Bioinformatics/10_Comprehensions/01_comprehensions.ipynb) |
# | 11 | **Iterators & Generators** | Memory-efficient processing | [01_iterators_and_generators.ipynb](Tier_1_Python_for_Bioinformatics/11_Iterators_and_Generators/01_iterators_and_generators.ipynb) |
#
# ### Part C: Advanced Python
#
# | # | Topic | Description | Key Skills |
# |---|-------|-------------|------------|
# | 12 | **Regular Expressions** | Motif finding, pattern matching | [01_regular_expressions.ipynb](Tier_1_Python_for_Bioinformatics/12_Regular_Expressions/01_regular_expressions.ipynb) |
# | 13 | **Classes & OOP** | DNA/Protein classes, inheritance | [01_classes_and_oop.ipynb](Tier_1_Python_for_Bioinformatics/13_Classes_and_OOP/01_classes_and_oop.ipynb) |
# | 14 | **Decorators & Context Managers** | Timing, caching, file handling | [01_decorators_and_context_managers.ipynb](Tier_1_Python_for_Bioinformatics/14_Decorators_and_Context_Managers/01_decorators_and_context_managers.ipynb) |
# | 15 | **Error Handling** | Robust bioinformatics code | [01_error_handling.ipynb](Tier_1_Python_for_Bioinformatics/15_Error_Handling/01_error_handling.ipynb) |
#
# ### Part D: Data Science Tools
#
# | # | Topic | Description | Key Skills |
# |---|-------|-------------|------------|
# | 16 | **NumPy & Pandas** | Arrays, DataFrames | [01_numpy_and_pandas.ipynb](Tier_1_Python_for_Bioinformatics/16_NumPy_and_Pandas/01_numpy_and_pandas.ipynb) |
# | 17 | **Data Wrangling** | Cleaning, transformation | [01_data_wrangling.ipynb](Tier_1_Python_for_Bioinformatics/17_Data_Wrangling/01_data_wrangling.ipynb) |
# | 18 | **Data Visualization** | matplotlib, seaborn, plots | [01_data_visualization.ipynb](Tier_1_Python_for_Bioinformatics/18_Data_Visualization/01_data_visualization.ipynb) |
#
# **🎓 After Tier 1:** You can write production-quality Python code for data analysis.

# %% [markdown]
# ---
#
# ## 🔬 Tier 2: Core Bioinformatics
# *Essential bioinformatics algorithms and tools*
#
# | # | Topic | Description | Key Skills |
# |---|-------|-------------|------------|
# | 0 | **Skills Check** | Test your bioinformatics knowledge | [00_skills_check.ipynb](Tier_2_Core_Bioinformatics/00_Skills_Check/00_skills_check.ipynb) |
# | 1 | **Biological Databases** | NCBI, UniProt, Ensembl | [01_biological_databases.ipynb](Tier_2_Core_Bioinformatics/01_Biological_Databases/01_biological_databases.ipynb) |
# | 2 | **BioPython Essentials** | Seq, SeqIO, SeqRecord | [01_biopython_essentials.ipynb](Tier_2_Core_Bioinformatics/02_BioPython_Essentials/01_biopython_essentials.ipynb) |
# | 3 | **Pairwise Alignment** | Needleman-Wunsch, Smith-Waterman | [01_pairwise_sequence_alignment.ipynb](Tier_2_Core_Bioinformatics/03_Pairwise_Sequence_Alignment/01_pairwise_sequence_alignment.ipynb) |
# | 4 | **BLAST Searching** | Homology search, E-values | [01_blast_searching.ipynb](Tier_2_Core_Bioinformatics/04_BLAST_Searching/01_blast_searching.ipynb) |
# | 5 | **Multiple Alignment** | ClustalW, MUSCLE, T-Coffee | [01_multiple_sequence_alignment.ipynb](Tier_2_Core_Bioinformatics/05_Multiple_Sequence_Alignment/01_multiple_sequence_alignment.ipynb) |
# | 6 | **Phylogenetics** | Trees, clustering, evolution | [01_phylogenetics.ipynb](Tier_2_Core_Bioinformatics/06_Phylogenetics/01_phylogenetics.ipynb) |
# | 7 | **Protein Structure** | PDB, visualization, analysis | [01_protein_structure.ipynb](Tier_2_Core_Bioinformatics/07_Protein_Structure/01_protein_structure.ipynb) |
# | 8 | **Nucleic Acid Structure** | DNA forms, RNA folding | [01_nucleic_acid_structure.ipynb](Tier_2_Core_Bioinformatics/08_Nucleic_Acid_Structure/01_nucleic_acid_structure.ipynb) |
# | 9 | **Chromatogram Analysis** | Sanger sequencing data | [01_chromatogram_analysis.ipynb](Tier_2_Core_Bioinformatics/09_Chromatogram_Analysis/01_chromatogram_analysis.ipynb) |
# | 10 | **Motifs & Domains** | PWMs, Pfam, PROSITE | [01_sequence_motifs_and_domains.ipynb](Tier_2_Core_Bioinformatics/10_Sequence_Motifs_and_Domains/01_sequence_motifs_and_domains.ipynb) |
# | 11 | **Gene Ontology** | GO terms, KEGG pathways | [01_gene_ontology_and_pathways.ipynb](Tier_2_Core_Bioinformatics/11_Gene_Ontology_and_Pathways/01_gene_ontology_and_pathways.ipynb) |
# | 12 | **Comparative Genomics** | Dotplots, synteny | [01_comparative_genomics.ipynb](Tier_2_Core_Bioinformatics/12_Comparative_Genomics/01_comparative_genomics.ipynb) |
#
# **🎓 After Tier 2:** You can perform standard bioinformatics analyses and understand core algorithms.

# %% [markdown]
# ---
#
# ## 🚀 Tier 3: Applied Bioinformatics
# *Advanced topics and real-world applications*
#
# | # | Topic | Description | Key Skills |
# |---|-------|-------------|------------|
# | 0 | **Skills Check** | Test your advanced knowledge | [00_skills_check.ipynb](Tier_3_Applied_Bioinformatics/00_Skills_Check/00_skills_check.ipynb) |
# | 1 | **NGS Fundamentals** | FASTQ, quality control | [01_ngs_fundamentals.ipynb](Tier_3_Applied_Bioinformatics/01_NGS_Fundamentals/01_ngs_fundamentals.ipynb) |
# | 2 | **Variant Calling** | SNPs, indels, VCF files | [01_variant_calling_and_snp_analysis.ipynb](Tier_3_Applied_Bioinformatics/02_Variant_Calling_and_SNP_Analysis/01_variant_calling_and_snp_analysis.ipynb) |
# | 3 | **RNA-seq Analysis** | Differential expression | [01_rna_seq_analysis.ipynb](Tier_3_Applied_Bioinformatics/03_RNA_seq_Analysis/01_rna_seq_analysis.ipynb) |
# | 4 | **Microbial Diversity** | 16S, metagenomics | [01_microbial_diversity.ipynb](Tier_3_Applied_Bioinformatics/04_Microbial_Diversity/01_microbial_diversity.ipynb) |
# | 5 | **Regulatory Analysis** | Promoters, TF binding | [01_promoter_and_regulatory_analysis.ipynb](Tier_3_Applied_Bioinformatics/05_Promoter_and_Regulatory_Analysis/01_promoter_and_regulatory_analysis.ipynb) |
# | 6 | **Statistics for Bio** | Multiple testing, FDR | [01_statistics_for_bioinformatics.ipynb](Tier_3_Applied_Bioinformatics/06_Statistics_for_Bioinformatics/01_statistics_for_bioinformatics.ipynb) |
# | 7 | **Machine Learning** | Classification, clustering | [01_machine_learning_for_biology.ipynb](Tier_3_Applied_Bioinformatics/07_Machine_Learning_for_Biology/01_machine_learning_for_biology.ipynb) |
# | 8 | **Capstone Project** | Integrate all skills | [01_capstone_project.ipynb](Tier_3_Applied_Bioinformatics/08_Capstone_Project/01_capstone_project.ipynb) |
# | 9 | **Molecular Modeling** | Docking, drug design | [01_molecular_modeling_and_docking.ipynb](Tier_3_Applied_Bioinformatics/09_Molecular_Modeling_and_Docking/01_molecular_modeling_and_docking.ipynb) |
# | 10 | **Deep Learning** | Neural networks for biology | [01_deep_learning_for_biology.ipynb](Tier_3_Applied_Bioinformatics/10_Deep_Learning_for_Biology/01_deep_learning_for_biology.ipynb) |
# | 11 | **Clinical Genomics** | Precision medicine | [01_clinical_genomics.ipynb](Tier_3_Applied_Bioinformatics/11_Clinical_Genomics/01_clinical_genomics.ipynb) |
#
# **🎓 After Tier 3:** You can tackle real-world bioinformatics research problems.

# %% [markdown]
# ---
#
# ## 📂 Additional Resources
#
# ### Legacy Modules (Extended Coverage)
#
# These modules contain additional materials from integrated courses:
#
# | Module | Content | Best For |
# |--------|---------|----------|
# | [06_Applied_Bioinformatics_IAB](06_Applied_Bioinformatics_IAB/) | IAB course exercises | Algorithm deep-dives |
# | [07_Kodomo_Structural_Bioinformatics](07_Kodomo_Structural_Bioinformatics/) | Structural biology | Crystallography, PDB |
#
# ### Assignment Notebooks
#
# Practice problems organized by week:
#
# | Week | Topics | Location |
# |------|--------|----------|
# | 1 | Python Basics | [Assignments/Week_01_Basics/](../Assignments/Week_01_Basics/) |
# | 2 | Data Structures | [Assignments/Week_02_DataStructures/](../Assignments/Week_02_DataStructures/) |
# | 3 | Advanced Python | [Assignments/Week_03_Advanced/](../Assignments/Week_03_Advanced/) |
# | 4 | Data Analysis | [Assignments/Week_04_Analysis/](../Assignments/Week_04_Analysis/) |
# | 5 | Bioinformatics | [Assignments/Week_05_Bioinformatics/](../Assignments/Week_05_Bioinformatics/) |
#
# ### Data Files
#
# Example data for exercises:
#
# ```
# Data/
# ├── fasta_examples/     # Sample FASTA files
# ├── pdb_examples/       # Protein structure files
# ├── csv_examples/       # Gene expression data
# ├── sequences/          # DNA/RNA/protein sequences
# ├── ngs/                # NGS sample data
# └── chromatograms/      # Sanger sequencing traces
# ```

# %% [markdown]
# ---
#
# ## 🛠️ Quick Setup
#
# Run this cell to verify your environment:

# %%
import sys
print(f"Python: {sys.version}")

# Check required packages
packages = {
    'numpy': 'NumPy (arrays)',
    'pandas': 'Pandas (DataFrames)',
    'matplotlib': 'Matplotlib (plotting)',
    'seaborn': 'Seaborn (statistics)',
    'Bio': 'BioPython (bioinformatics)',
    'scipy': 'SciPy (scientific computing)',
    'sklearn': 'Scikit-learn (ML)'
}

print("\nPackage Status:")
print("-" * 40)
for pkg, desc in packages.items():
    try:
        __import__(pkg)
        print(f"✅ {desc}")
    except ImportError:
        print(f"❌ {desc} - install with: pip install {pkg.lower()}")

print("\n" + "="*40)
print("🚀 Ready to start learning!")

# %% [markdown]
# ---
#
# ## 📖 Learning Tips
#
# 1. **Run every code cell** - Don't just read, execute!
# 2. **Experiment** - Modify examples to see what happens
# 3. **Use the assignments** - Practice is essential
# 4. **Build projects** - Apply skills to your own data
# 5. **Ask questions** - Use Stack Overflow, BioPython forums
#
# ---
#
# ## 🎯 Start Here
#
# 👉 **New to programming?** Start with [Tier 0: Linux Basics](Tier_0_Computational_Foundations/01_Linux_Basics/01_linux_fundamentals.ipynb)
#
# 👉 **Know basics, new to Python?** Start with [Tier 1: Python Introduction](Tier_1_Python_for_Bioinformatics/01_Python_Introduction/01_python_introduction.ipynb)
#
# 👉 **Know Python, new to bioinformatics?** Start with [Tier 2: BioPython](Tier_2_Core_Bioinformatics/02_BioPython_Essentials/01_biopython_essentials.ipynb)
#
# 👉 **Ready for advanced topics?** Start with [Tier 3: NGS Fundamentals](Tier_3_Applied_Bioinformatics/01_NGS_Fundamentals/01_ngs_fundamentals.ipynb)
#
# ---
#
# **Happy Learning! 🧬🐍**
