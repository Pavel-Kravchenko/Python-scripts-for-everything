# %% [markdown]
# # Tier 4 Skills Check: Algorithms & Data Structures
#
# ---
#
# ## Can You Skip Ahead?
#
# This skills check will help you determine if you already know the material in Tier 4.
#
# **If you can solve 80% of these problems**, you likely have a solid foundation in algorithms and data structures. Feel free to skip ahead or use this tier as a reference.
#
# **If these problems feel challenging**, work through the modules in order — they build on each other.
#
# ---

# %% [markdown]
# ---
#
# [← Previous: TF Footprinting & Chromatin Accessibility](../../Tier_3_Applied_Bioinformatics/23_TF_Footprinting/23_tf_footprinting.ipynb) | [Next: 📊 Algorithmic Complexity Analysis & Big O Notation →](../../Tier_4_Algorithms_and_Data_Structures/01_Complexity_Analysis/01_complexity_analysis.ipynb)
#
# ---

# %% [markdown]
# ## Part 1: Complexity Analysis
#
# ### Question 1.1
#
# What is the time complexity of the following function?

# %%
def mystery(n):
    count = 0
    i = n
    while i > 0:
        for j in range(n):
            count += 1
        i = i // 2
    return count

# What is the Big-O time complexity?
# Your answer:

# %% [markdown]
# ### Question 1.2
#
# Rank these complexity classes from fastest to slowest:
#
# O(n²), O(1), O(n log n), O(2ⁿ), O(log n), O(n), O(n!)

# %%
# Your answer (from fastest to slowest):
ranking = []

# %% [markdown]
# ---
#
# ## Part 2: Sorting
#
# ### Question 2.1
#
# Implement QuickSort with the Lomuto partition scheme.

# %%
def quicksort(arr, low=0, high=None):
    """Sort array in-place using QuickSort."""
    # Your implementation here
    pass

# Test
test = [64, 34, 25, 12, 22, 11, 90]
quicksort(test)
assert test == [11, 12, 22, 25, 34, 64, 90], f"Expected sorted, got {test}"
print("QuickSort works!")

# %% [markdown]
# ### Question 2.2
#
# When would you use Counting Sort instead of QuickSort? What are its constraints?

# %%
# Your answer:
#

# %% [markdown]
# ---
#
# ## Part 3: Data Structures
#
# ### Question 3.1
#
# Implement a Stack using a linked list (not a Python list).

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Stack:
    def __init__(self):
        self.top = None
        self.size = 0
    
    def push(self, value):
        # Your implementation
        pass
    
    def pop(self):
        # Your implementation
        pass
    
    def peek(self):
        # Your implementation
        pass
    
    def is_empty(self):
        return self.size == 0

# Test
s = Stack()
s.push(1)
s.push(2)
s.push(3)
assert s.pop() == 3
assert s.peek() == 2
assert s.pop() == 2
assert s.pop() == 1
assert s.is_empty()
print("Stack works!")

# %% [markdown]
# ### Question 3.2
#
# What is the time complexity for the following operations in a hash table with good hash function?
#
# - Insert: ?
# - Search: ?
# - Delete: ?
# - Worst case for all: ?

# %%
# Your answers:
hash_table_complexity = {
    "insert_average": "",
    "search_average": "",
    "delete_average": "",
    "worst_case": ""
}

# %% [markdown]
# ---
#
# ## Part 4: Trees
#
# ### Question 4.1
#
# Given a Binary Search Tree, implement in-order traversal (iteratively, without recursion).

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def inorder_iterative(root):
    """Return list of values in in-order sequence."""
    result = []
    # Your implementation (use a stack, no recursion)
    
    return result

# Test
#       4
#      / \
#     2   6
#    / \ / \
#   1  3 5  7
root = TreeNode(4)
root.left = TreeNode(2)
root.right = TreeNode(6)
root.left.left = TreeNode(1)
root.left.right = TreeNode(3)
root.right.left = TreeNode(5)
root.right.right = TreeNode(7)

assert inorder_iterative(root) == [1, 2, 3, 4, 5, 6, 7]
print("In-order traversal works!")

# %% [markdown]
# ### Question 4.2
#
# What makes an AVL tree different from a regular BST? What is the balance factor?

# %%
# Your answer:
#

# %% [markdown]
# ---
#
# ## Part 5: String Algorithms
#
# ### Question 5.1
#
# Implement the KMP failure function (partial match table).

# %%
def compute_lps(pattern):
    """Compute Longest Proper Prefix which is also Suffix (LPS) array."""
    lps = [0] * len(pattern)
    # Your implementation
    
    return lps

# Test
assert compute_lps("AAAA") == [0, 1, 2, 3]
assert compute_lps("ABCABC") == [0, 0, 0, 1, 2, 3]
assert compute_lps("AABAACAABAA") == [0, 1, 0, 1, 2, 0, 1, 2, 3, 4, 5]
print("KMP failure function works!")

# %% [markdown]
# ### Question 5.2
#
# What is a Trie? When would you use it instead of a hash table for string lookups?

# %%
# Your answer:
#

# %% [markdown]
# ---
#
# ## Scoring
#
# | Section | Max Points |
# |---------|------------|
# | Part 1: Complexity | 20 |
# | Part 2: Sorting | 20 |
# | Part 3: Data Structures | 20 |
# | Part 4: Trees | 20 |
# | Part 5: String Algorithms | 20 |
# | **Total** | **100** |
#
# ### Interpretation
#
# - **80-100**: You have a strong foundation — use Tier 4 as a reference
# - **60-79**: Solid basics but review specific modules where you struggled
# - **40-59**: Work through the tier, focusing on weak areas
# - **0-39**: Start from Module 1 and work through systematically
#
# ---
#
# ## Next Steps
#
# Ready to learn or review? Start with **Module 1: Complexity Analysis** →

# %% [markdown]
# ---
#
# [← Previous: TF Footprinting & Chromatin Accessibility](../../Tier_3_Applied_Bioinformatics/23_TF_Footprinting/23_tf_footprinting.ipynb) | [Next: 📊 Algorithmic Complexity Analysis & Big O Notation →](../../Tier_4_Algorithms_and_Data_Structures/01_Complexity_Analysis/01_complexity_analysis.ipynb)
