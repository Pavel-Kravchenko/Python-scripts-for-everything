# %% [markdown]
# # Sequence Motifs + Domains: Overview
#
# This overview links to separate, self-contained notebooks for each topic.
#
# 1. [Sequence Motifs](./01_sequence_motifs.ipynb)
# 2. [Domains](./02_domains.ipynb)
#
# **Navigation:** [Back to tier](../README.md) · [Open Sequence Motifs](./01_sequence_motifs.ipynb)

# %% [markdown]
# ---
#
# [< Previous: Sequence Motifs](01_sequence_motifs.ipynb) | [Tier 2: Core Bioinformatics Overview](../README.md) | [Next: Domains >](02_domains.ipynb)
#
# ---

# %% [markdown]
# ---
#
# [< Previous: Sequence Motifs](01_sequence_motifs.ipynb) | [Tier 2: Core Bioinformatics Overview](../README.md) | [Next: Domains >](02_domains.ipynb)
#
# ---
