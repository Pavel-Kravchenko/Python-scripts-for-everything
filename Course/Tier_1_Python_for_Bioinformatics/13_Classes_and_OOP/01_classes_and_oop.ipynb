# %% [markdown]
# # Classes + Oop: Overview
#
# This overview links to separate, self-contained notebooks for each topic.
#
# 1. [Classes](./01_classes.ipynb)
# 2. [Oop](./02_oop.ipynb)
#
# **Navigation:** [Back to tier](../README.md) · [Open Classes](./01_classes.ipynb)

# %% [markdown]
# ---
#
# [< Previous: Classes](01_classes.ipynb) | [Tier 1: Python for Bioinformatics Overview](../README.md) | [Next: Oop >](02_oop.ipynb)
#
# ---

# %% [markdown]
# ---
#
# [< Previous: Classes](01_classes.ipynb) | [Tier 1: Python for Bioinformatics Overview](../README.md) | [Next: Oop >](02_oop.ipynb)
#
# ---
