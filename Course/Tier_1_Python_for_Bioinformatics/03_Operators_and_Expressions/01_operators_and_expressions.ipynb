# %% [markdown]
# # Operators + Expressions: Overview
#
# Master Python operators — arithmetic, comparison, logical, membership, and string operators — with biological examples throughout.
#
# ## Notebooks in this module
#
# 1. [Operators](./01_operators.ipynb) — click to open
# 2. [Expressions](./02_expressions.ipynb) — click to open
#
# **Recommendation:** work through notebook 1, then notebook 2. Each is self-contained.

# %% [markdown]
# ---
#
# [← Previous: Module 2: Variables and Data Types](../02_Variables_and_Data_Types/01_variables_and_data_types.ipynb) | [Next: Operators →](./01_operators.ipynb)
#
# ---

# %% [markdown]
# ---
#
# [← Back to Operators](./01_operators.ipynb) | [Next: Module 4: Strings and Biological Sequences →](../04_Strings_and_Sequences/01_strings_and_sequences.ipynb)
#
# ---
