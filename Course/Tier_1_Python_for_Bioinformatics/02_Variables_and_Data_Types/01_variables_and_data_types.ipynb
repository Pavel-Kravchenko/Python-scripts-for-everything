# %% [markdown]
# # Variables + Data Types: Overview
#
# This overview links to separate, self-contained notebooks for each topic.
#
# 1. [Variables](./01_variables.ipynb)
# 2. [Data Types](./02_data_types.ipynb)
#
# **Navigation:** [Back to tier](../README.md) · [Open Variables](./01_variables.ipynb)
