# %% [markdown]
# # Variables + Data Types: Overview
#
# Learn how Python names and stores data, then explore the five core types: `int`, `float`, `str`, `bool`, and `None`.
#
# ## Notebooks in this module
#
# 1. [Variables](./01_variables.ipynb) — click to open
# 2. [Data Types](./02_data_types.ipynb) — click to open
#
# **Recommendation:** work through notebook 1, then notebook 2. Each is self-contained.

# %% [markdown]
# ---
#
# [← Previous: Module 1: Python Introduction](../01_Python_Introduction/01_python_introduction.ipynb) | [Next: Variables →](./01_variables.ipynb)
#
# ---

# %% [markdown]
# ---
#
# [← Back to Variables](./01_variables.ipynb) | [Next: Module 3: Operators and Expressions →](../03_Operators_and_Expressions/01_operators_and_expressions.ipynb)
#
# ---
