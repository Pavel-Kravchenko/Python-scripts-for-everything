# %% [markdown]
# # Lists + Tuples: Overview
#
# This overview links to separate, self-contained notebooks for each topic.
#
# 1. [Lists](./01_lists.ipynb)
# 2. [Tuples](./02_tuples.ipynb)
#
# **Navigation:** [Back to tier](../README.md) · [Open Lists](./01_lists.ipynb)
