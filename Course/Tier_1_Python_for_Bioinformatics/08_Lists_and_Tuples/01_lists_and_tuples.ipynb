# %% [markdown]
# # Lists + Tuples: Overview
#
# Lists store ordered, mutable collections of sequences and expression values. Tuples store fixed records like genomic coordinates. Both are indispensable.
#
# ## Notebooks in this module
#
# 1. [Lists](./01_lists.ipynb) — click to open
# 2. [Tuples](./02_tuples.ipynb) — click to open
#
# **Recommendation:** work through notebook 1, then notebook 2. Each is self-contained.

# %% [markdown]
# ---
#
# [← Previous: Module 7: File Operations](../07_File_Operations/01_file_operations.ipynb) | [Next: Lists →](./01_lists.ipynb)
#
# ---

# %% [markdown]
# ---
#
# [← Back to Lists](./01_lists.ipynb) | [Next: Module 9: Dictionaries and Sets →](../09_Dictionaries_and_Sets/01_dictionaries_and_sets.ipynb)
#
# ---
