# %% [markdown]
# # Decorators + Context Managers: Overview
#
# This overview links to separate, self-contained notebooks for each topic.
#
# 1. [Decorators](./01_decorators.ipynb)
# 2. [Context Managers](./02_context_managers.ipynb)
#
# **Navigation:** [Back to tier](../README.md) · [Open Decorators](./01_decorators.ipynb)

# %% [markdown]
# ---
#
# [< Previous: Decorators](01_decorators.ipynb) | [Tier 1: Python for Bioinformatics Overview](../README.md) | [Next: Context Managers >](02_context_managers.ipynb)
#
# ---

# %% [markdown]
# ---
#
# [< Previous: Decorators](01_decorators.ipynb) | [Tier 1: Python for Bioinformatics Overview](../README.md) | [Next: Context Managers >](02_context_managers.ipynb)
#
# ---
