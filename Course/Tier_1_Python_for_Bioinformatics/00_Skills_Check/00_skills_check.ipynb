# %% [markdown]
# # Tier 1 Skills Check: Can You Skip Ahead?
#
# **Estimated time: 20-30 minutes**
#
# ---
#
# This self-assessment will help you decide whether you already have the Python skills covered in **Tier 1: Python for Bioinformatics**. Work through the 15 questions below *without* running code or looking anything up.
#
# ### Scoring
#
# | Score | Recommendation |
# |-------|----------------|
# | 13-15 correct | You can safely skip Tier 1 and proceed to Tier 2 |
# | 9-12 correct | Skim Tier 1 notebooks, focusing on the topics you missed |
# | 0-8 correct | Work through Tier 1 from the beginning -- it will be time well spent |
#
# Write your answers in the empty code cells, then scroll to the **Answer Key** at the bottom to check.
#
# ---

# %% [markdown]
# ---
#
# [← Previous: R Regression, Correlation, and Diagnostics](../../Tier_0_Computational_Foundations/08_Advanced_R_Statistics/02_r_regression_correlation_and_diagnostics.ipynb) | [Next: Module 1: Python Introduction for Bioinformatics →](../../Tier_1_Python_for_Bioinformatics/01_Python_Introduction/01_python_introduction.ipynb)
#
# ---

# %% [markdown]
# ## Question 1: Variables and Types
#
# What does the following code print?
#
# ```python
# dna = "ATCGATCG"
# print(type(dna), len(dna))
# ```

# %%
# Your answer for Q1:

# %% [markdown]
# ## Question 2: Type Conversion
#
# What does the following code print?
#
# ```python
# gc_content = 0.487
# print(int(gc_content * 100))
# ```

# %%
# Your answer for Q2:

# %% [markdown]
# ## Question 3: String Slicing
#
# What does the following code print?
#
# ```python
# dna = "ATGAAACCCGGGTAA"
# print(dna[0:3], dna[-3:])
# ```

# %%
# Your answer for Q3:

# %% [markdown]
# ## Question 4: String Methods
#
# What does the following code print?
#
# ```python
# dna = "ATCGATCG"
# rna = dna.replace("T", "U")
# print(rna)
# ```

# %%
# Your answer for Q4:

# %% [markdown]
# ## Question 5: Arithmetic Operators
#
# A DNA sequence has 900 nucleotides. What do the following expressions evaluate to?
#
# ```python
# seq_len = 900
# print(seq_len // 3)
# print(seq_len % 3)
# ```

# %%
# Your answer for Q5:

# %% [markdown]
# ## Question 6: Lists
#
# What does the following code print?
#
# ```python
# genes = ["BRCA1", "TP53", "EGFR"]
# genes.append("MYC")
# genes.pop(1)
# print(genes)
# ```

# %%
# Your answer for Q6:

# %% [markdown]
# ## Question 7: Dictionaries
#
# What does the following code print?
#
# ```python
# codon_table = {"ATG": "Met", "TAA": "Stop", "GGG": "Gly"}
# codon_table["AAA"] = "Lys"
# print(len(codon_table))
# print("TAA" in codon_table)
# ```

# %%
# Your answer for Q7:

# %% [markdown]
# ## Question 8: For Loops
#
# What does the following code print?
#
# ```python
# dna = "ATCGATCG"
# count = 0
# for nuc in dna:
#     if nuc == "G" or nuc == "C":
#         count += 1
# print(count)
# ```

# %%
# Your answer for Q8:

# %% [markdown]
# ## Question 9: List Comprehension
#
# What does the following code produce?
#
# ```python
# dna = "ATGAAACCCGGGTAA"
# codons = [dna[i:i+3] for i in range(0, len(dna), 3)]
# print(codons)
# ```

# %%
# Your answer for Q9:

# %% [markdown]
# ## Question 10: Functions
#
# What does the following code print?
#
# ```python
# def gc_content(seq):
#     gc = sum(1 for nuc in seq if nuc in "GC")
#     return gc / len(seq)
#
# result = gc_content("AATTGGCC")
# print(result)
# ```

# %%
# Your answer for Q10:

# %% [markdown]
# ## Question 11: Default Arguments and Return Values
#
# What does the following code print?
#
# ```python
# def transcribe(dna, reverse=False):
#     rna = dna.replace("T", "U")
#     if reverse:
#         return rna[::-1]
#     return rna
#
# print(transcribe("ATGC"))
# print(transcribe("ATGC", reverse=True))
# ```

# %%
# Your answer for Q11:

# %% [markdown]
# ## Question 12: File I/O
#
# The file `genes.txt` contains:
# ```
# BRCA1
# TP53
# EGFR
# ```
#
# What does the following code produce?
#
# ```python
# with open("genes.txt") as f:
#     genes = [line.strip() for line in f]
# print(genes)
# print(len(genes))
# ```

# %%
# Your answer for Q12:

# %% [markdown]
# ## Question 13: Nested Data Structures
#
# What does the following code print?
#
# ```python
# experiments = {
#     "sample_A": {"gene": "BRCA1", "expression": 12.5},
#     "sample_B": {"gene": "TP53", "expression": 8.3},
# }
#
# for sample, data in experiments.items():
#     if data["expression"] > 10:
#         print(f"{sample}: {data['gene']}")
# ```

# %%
# Your answer for Q13:

# %% [markdown]
# ## Question 14: Classes
#
# What does the following code print?
#
# ```python
# class Gene:
#     def __init__(self, name, sequence):
#         self.name = name
#         self.sequence = sequence
#
#     def length(self):
#         return len(self.sequence)
#
# g = Gene("BRCA1", "ATGCGATCG")
# print(g.name, g.length())
# ```

# %%
# Your answer for Q14:

# %% [markdown]
# ## Question 15: Putting It All Together
#
# What does the following code print?
#
# ```python
# def find_orfs(dna):
#     """Find all start-codon positions in reading frame 0."""
#     positions = []
#     for i in range(0, len(dna) - 2, 3):
#         if dna[i:i+3] == "ATG":
#             positions.append(i)
#     return positions
#
# seq = "ATGAAACCCATGGGG"
# result = find_orfs(seq)
# print(result)
# print(len(result))
# ```

# %%
# Your answer for Q15:

# %% [markdown]
# ---
#
# ## Answer Key
#
# Scroll down when you are ready to check your answers.
#
# <br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ### Q1 Answer
#
# ```
# <class 'str'> 8
# ```
#
# `"ATCGATCG"` is a string of length 8. **Topics**: basic types, `len()`.

# %% [markdown]
# ### Q2 Answer
#
# ```
# 48
# ```
#
# `0.487 * 100 = 48.7`, and `int()` truncates (does not round), so the result is `48`. **Topics**: float arithmetic, `int()` truncation.

# %% [markdown]
# ### Q3 Answer
#
# ```
# ATG TAA
# ```
#
# `dna[0:3]` gives the first three characters (the start codon). `dna[-3:]` gives the last three (the stop codon). **Topics**: string slicing, negative indices.

# %% [markdown]
# ### Q4 Answer
#
# ```
# AUCGAUCG
# ```
#
# `replace("T", "U")` performs DNA-to-RNA transcription by swapping thymine for uracil. **Topics**: string methods.

# %% [markdown]
# ### Q5 Answer
#
# ```
# 300
# 0
# ```
#
# `900 // 3 = 300` complete codons. `900 % 3 = 0` leftover nucleotides. **Topics**: floor division, modulo.

# %% [markdown]
# ### Q6 Answer
#
# ```
# ['BRCA1', 'EGFR', 'MYC']
# ```
#
# `append("MYC")` adds to the end. `pop(1)` removes the element at index 1 (`"TP53"`). **Topics**: list methods.

# %% [markdown]
# ### Q7 Answer
#
# ```
# 4
# True
# ```
#
# Adding `"AAA"` brings the dictionary to 4 entries. `"TAA" in codon_table` checks key membership. **Topics**: dictionaries, `in` operator.

# %% [markdown]
# ### Q8 Answer
#
# ```
# 4
# ```
#
# `"ATCGATCG"` contains G at positions 3 and 7, and C at positions 2 and 6 -- four GC nucleotides total. **Topics**: for loops, conditionals, counting.

# %% [markdown]
# ### Q9 Answer
#
# ```
# ['ATG', 'AAA', 'CCC', 'GGG', 'TAA']
# ```
#
# The list comprehension steps through the string in increments of 3, extracting each codon. **Topics**: list comprehension, `range()` with step, slicing.

# %% [markdown]
# ### Q10 Answer
#
# ```
# 0.5
# ```
#
# `"AATTGGCC"` has 4 GC nucleotides out of 8 total: 4/8 = 0.5. **Topics**: functions, generator expressions, `sum()`.

# %% [markdown]
# ### Q11 Answer
#
# ```
# AUGC
# CGUA
# ```
#
# The first call uses the default `reverse=False`, yielding `"AUGC"`. The second reverses the RNA string. **Topics**: default arguments, string reversal.

# %% [markdown]
# ### Q12 Answer
#
# ```
# ['BRCA1', 'TP53', 'EGFR']
# 3
# ```
#
# The `with` statement opens the file safely. The list comprehension reads each line and strips the trailing newline. **Topics**: file I/O, `with` statement, list comprehension.

# %% [markdown]
# ### Q13 Answer
#
# ```
# sample_A: BRCA1
# ```
#
# Only `sample_A` has expression > 10. **Topics**: nested dictionaries, `.items()`, f-strings.

# %% [markdown]
# ### Q14 Answer
#
# ```
# BRCA1 9
# ```
#
# The `Gene` class stores a name and sequence. `g.length()` returns `len("ATGCGATCG")` which is 9. **Topics**: classes, `__init__`, methods.

# %% [markdown]
# ### Q15 Answer
#
# ```
# [0, 9]
# 2
# ```
#
# The function scans in-frame (step 3). `"ATG"` appears at position 0 and position 9. **Topics**: functions, loops, slicing, list building.

# %% [markdown]
# ---
#
# ## Score Interpretation
#
# Count how many you got right and refer to the table at the top of this notebook.
#
# | Questions | Topic Covered |
# |-----------|---------------|
# | Q1-Q2 | Variables, types, type conversion |
# | Q3-Q4 | String slicing and methods |
# | Q5 | Arithmetic operators |
# | Q6-Q7 | Lists and dictionaries |
# | Q8-Q9 | Loops and list comprehensions |
# | Q10-Q11 | Functions |
# | Q12 | File I/O |
# | Q13 | Nested data structures |
# | Q14 | Classes |
# | Q15 | Combining multiple concepts |
#
# If you missed several questions in a particular topic area, focus on those modules in Tier 1.
#
# **Good luck with the course!**

# %% [markdown]
# ---
#
# [← Previous: R Regression, Correlation, and Diagnostics](../../Tier_0_Computational_Foundations/08_Advanced_R_Statistics/02_r_regression_correlation_and_diagnostics.ipynb) | [Next: Module 1: Python Introduction for Bioinformatics →](../../Tier_1_Python_for_Bioinformatics/01_Python_Introduction/01_python_introduction.ipynb)
