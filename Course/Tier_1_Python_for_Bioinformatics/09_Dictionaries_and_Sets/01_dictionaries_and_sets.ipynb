# %% [markdown]
# # Dictionaries + Sets: Overview
#
# This overview links to separate, self-contained notebooks for each topic.
#
# 1. [Dictionaries](./01_dictionaries.ipynb)
# 2. [Sets](./02_sets.ipynb)
#
# **Navigation:** [Back to tier](../README.md) · [Open Dictionaries](./01_dictionaries.ipynb)
