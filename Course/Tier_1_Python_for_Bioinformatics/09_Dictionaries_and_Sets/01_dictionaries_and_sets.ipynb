# %% [markdown]
# # Dictionaries + Sets: Overview
#
# Dictionaries map keys to values — perfect for codon tables, gene annotations, and frequency counts. Sets efficiently handle unique elements like gene lists and k-mer profiles.
#
# ## Notebooks in this module
#
# 1. [Dictionaries](./01_dictionaries.ipynb) — click to open
# 2. [Sets](./02_sets.ipynb) — click to open
#
# **Recommendation:** work through notebook 1, then notebook 2. Each is self-contained.

# %% [markdown]
# ---
#
# [← Previous: Module 8: Lists and Tuples](../08_Lists_and_Tuples/01_lists_and_tuples.ipynb) | [Next: Dictionaries →](./01_dictionaries.ipynb)
#
# ---

# %% [markdown]
# ---
#
# [← Back to Dictionaries](./01_dictionaries.ipynb) | [Next: Module 10: Comprehensions →](../10_Comprehensions/01_comprehensions.ipynb)
#
# ---
