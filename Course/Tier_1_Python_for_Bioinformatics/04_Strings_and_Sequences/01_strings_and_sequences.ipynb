# %% [markdown]
# # Strings + Biological Sequences: Overview
#
# DNA, RNA, and protein sequences are Python strings. Learn slicing, string methods, reverse complement, transcription, and FASTA parsing.
#
# ## Notebooks in this module
#
# 1. [Strings](./01_strings.ipynb) — click to open
# 2. [Sequences](./02_sequences.ipynb) — click to open
#
# **Recommendation:** work through notebook 1, then notebook 2. Each is self-contained.

# %% [markdown]
# ---
#
# [← Previous: Module 3: Operators and Expressions](../03_Operators_and_Expressions/01_operators_and_expressions.ipynb) | [Next: Strings →](./01_strings.ipynb)
#
# ---

# %% [markdown]
# ---
#
# [← Back to Strings](./01_strings.ipynb) | [Next: Module 5: Control Flow →](../05_Control_Flow/01_control_flow.ipynb)
#
# ---
