# %% [markdown]
# # Solution: 02 Vision Rag
#
# Matching assignment: `Assignments/Course_Topics/Tier_5_Modern_AI_for_Science/02_Vision_RAG/02_Vision_RAG.ipynb`
#
# **Navigation:** [Assignment](/`Assignments/Course_Topics/Tier_5_Modern_AI_for_Science/02_Vision_RAG/02_Vision_RAG.ipynb`) · [Course topic](/`Course/Tier_5_Modern_AI_for_Science/02_Vision_RAG/02_Vision_RAG.ipynb`)

# %% [markdown]
# ## Complicated moments explained
# These are common points where learners usually get stuck:
# - Model score != biological truth. Treat predictions as ranked hypotheses requiring validation.
# - Context length and tokenization can change model behavior more than minor hyperparameter tweaks.
# - Domain shift is common: performance on curated benchmarks may not transfer to your assay/data source.

# %% [markdown]
# ## Reference Solution
#
# - Concept summary: provide concise key points from the source notebook.
# - Method reproduction: include a working implementation with reproducible inputs.
# - Extension: include one variation and compare outcomes.
# - Limitations: include caveats and potential failure modes.

# %%
# Reference implementation
# (Fill with final solved code for this topic)
