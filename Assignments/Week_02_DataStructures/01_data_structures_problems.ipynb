# %% [markdown]
# # 📝 Week 2 Assignment: Data Structures & Comprehensions
# # Задания по структурам данных
#
# ---
#
# These exercises focus on:
# - Lists, tuples, and slicing for sequences
# - Dictionaries for genetic codes and mappings
# - Sets for unique elements
# - List/dict/set comprehensions
# - K-mer analysis
#
# ---

# %% [markdown]
# ## 🧬 Problem 1: Codon Extraction
#
# Write a function that extracts all codons from a DNA sequence in all three reading frames.
#
# ```
# Example:
# Input:  "ATGGCCGATCGA"
# Output: {
#     0: ['ATG', 'GCC', 'GAT', 'CGA'],
#     1: ['TGG', 'CCG', 'ATC'],
#     2: ['GGC', 'CGA', 'TCG']
# }
# ```

# %%
def extract_codons_all_frames(sequence):
    """
    Extract codons from all three reading frames.
    
    Args:
        sequence: DNA sequence string
        
    Returns:
        Dictionary with frame number (0,1,2) as key and list of codons as value
    """
    # YOUR CODE HERE
    pass

# Test your function
test_seq = "ATGGCCGATCGA"
result = extract_codons_all_frames(test_seq)
print(result)

# %% [markdown]
# ## 🧬 Problem 2: Genetic Code Dictionary
#
# Create a function that translates a DNA sequence to protein using a codon dictionary.
# Stop at the first stop codon (TAA, TAG, TGA).
#
# ```
# Example:
# Input:  "ATGGCCGATTAA"
# Output: "MAD"
# ```

# %%
# Genetic Code Dictionary
CODON_TABLE = {
    'TTT': 'F', 'TTC': 'F', 'TTA': 'L', 'TTG': 'L',
    'TCT': 'S', 'TCC': 'S', 'TCA': 'S', 'TCG': 'S',
    'TAT': 'Y', 'TAC': 'Y', 'TAA': '*', 'TAG': '*',
    'TGT': 'C', 'TGC': 'C', 'TGA': '*', 'TGG': 'W',
    'CTT': 'L', 'CTC': 'L', 'CTA': 'L', 'CTG': 'L',
    'CCT': 'P', 'CCC': 'P', 'CCA': 'P', 'CCG': 'P',
    'CAT': 'H', 'CAC': 'H', 'CAA': 'Q', 'CAG': 'Q',
    'CGT': 'R', 'CGC': 'R', 'CGA': 'R', 'CGG': 'R',
    'ATT': 'I', 'ATC': 'I', 'ATA': 'I', 'ATG': 'M',
    'ACT': 'T', 'ACC': 'T', 'ACA': 'T', 'ACG': 'T',
    'AAT': 'N', 'AAC': 'N', 'AAA': 'K', 'AAG': 'K',
    'AGT': 'S', 'AGC': 'S', 'AGA': 'R', 'AGG': 'R',
    'GTT': 'V', 'GTC': 'V', 'GTA': 'V', 'GTG': 'V',
    'GCT': 'A', 'GCC': 'A', 'GCA': 'A', 'GCG': 'A',
    'GAT': 'D', 'GAC': 'D', 'GAA': 'E', 'GAG': 'E',
    'GGT': 'G', 'GGC': 'G', 'GGA': 'G', 'GGG': 'G'
}

def translate_dna(sequence):
    """
    Translate DNA sequence to protein.
    Stop translation at stop codon.
    
    Args:
        sequence: DNA sequence string
        
    Returns:
        Protein sequence string
    """
    # YOUR CODE HERE
    pass

# Test
print(translate_dna("ATGGCCGATTAA"))  # Expected: MAD

# %% [markdown]
# ## 🧬 Problem 3: K-mer Counter
#
# Write a function that counts all k-mers in a sequence and returns them sorted by frequency.
#
# ```
# Example:
# Input:  "ATGATGATG", k=3
# Output: [('ATG', 3), ('TGA', 2), ('GAT', 2)]
# ```

# %%
def count_kmers(sequence, k):
    """
    Count all k-mers in sequence.
    
    Args:
        sequence: DNA sequence string
        k: length of k-mer
        
    Returns:
        List of tuples (kmer, count) sorted by count descending
    """
    # YOUR CODE HERE
    # Hint: Use a dictionary comprehension or Counter
    pass

# Test
result = count_kmers("ATGATGATG", 3)
print(result)

# %% [markdown]
# ## 🧬 Problem 4: Set Operations for Sequences
#
# Given two sets of protein sequences, find:
# 1. Proteins present in both samples (intersection)
# 2. Proteins unique to each sample
# 3. All proteins combined (union)
#
# ```
# Example:
# sample1 = {"ProteinA", "ProteinB", "ProteinC"}
# sample2 = {"ProteinB", "ProteinC", "ProteinD"}
#
# shared:        {"ProteinB", "ProteinC"}
# unique_to_1:   {"ProteinA"}
# unique_to_2:   {"ProteinD"}
# all_proteins:  {"ProteinA", "ProteinB", "ProteinC", "ProteinD"}
# ```

# %%
def compare_protein_sets(sample1, sample2):
    """
    Compare two sets of proteins.
    
    Args:
        sample1: set of protein names
        sample2: set of protein names
        
    Returns:
        Dictionary with keys: 'shared', 'unique_to_1', 'unique_to_2', 'all'
    """
    # YOUR CODE HERE
    pass

# Test
s1 = {"ProteinA", "ProteinB", "ProteinC"}
s2 = {"ProteinB", "ProteinC", "ProteinD"}
result = compare_protein_sets(s1, s2)
print(result)

# %% [markdown]
# ## 🧬 Problem 5: Comprehension Challenge
#
# Use list comprehensions to solve these tasks:
#
# 1. Extract all positions where 'ATG' starts in a sequence
# 2. Create a dictionary mapping each amino acid to its possible codons
# 3. Filter a list of sequences to keep only those with GC content > 50%

# %%
# Task 5a: Find all ATG positions
def find_atg_positions(sequence):
    """Return list of positions where 'ATG' starts (0-indexed)"""
    # YOUR CODE HERE - use list comprehension
    pass

# Test
test = "ATGCCATGGATG"
print(find_atg_positions(test))  # Expected: [0, 5, 9]

# %%
# Task 5b: Reverse codon table (amino acid -> list of codons)
def reverse_codon_table(codon_table):
    """
    Create reverse mapping: amino acid -> list of codons that encode it.
    
    Example output:
    {'F': ['TTT', 'TTC'], 'L': ['TTA', 'TTG', ...], ...}
    """
    # YOUR CODE HERE
    pass

# Test
reverse_table = reverse_codon_table(CODON_TABLE)
print(f"Codons for Leucine (L): {reverse_table.get('L')}")

# %%
# Task 5c: Filter by GC content
def gc_content(seq):
    """Calculate GC content as percentage"""
    gc = seq.count('G') + seq.count('C')
    return (gc / len(seq)) * 100

def filter_high_gc(sequences, threshold=50):
    """
    Filter sequences with GC content above threshold.
    Use list comprehension.
    """
    # YOUR CODE HERE
    pass

# Test
seqs = ["ATATATAT", "GCGCGCGC", "ATGCATGC", "AAAAAAA"]
high_gc = filter_high_gc(seqs, 50)
print(high_gc)  # Expected: ['GCGCGCGC', 'ATGCATGC']

# %% [markdown]
# ## 🧬 Problem 6: Nucleotide Pair Counter (From Rosalind)
#
# Count all dinucleotide (2-mer) frequencies in a sequence.
# Return results as a formatted table.
#
# ```
# Example:
# Input:  "ATGCATGC"
# Output:
#    A  T  G  C
# A  0  1  0  1
# T  0  0  2  0
# G  0  0  0  2
# C  1  0  0  0
# ```

# %%
def count_dinucleotides(sequence):
    """
    Count all dinucleotide pairs.
    
    Returns:
        Dictionary of dictionaries: {first_nuc: {second_nuc: count}}
    """
    nucleotides = ['A', 'T', 'G', 'C']
    # YOUR CODE HERE
    pass

def print_dinucleotide_table(counts):
    """Print the dinucleotide counts as a formatted table"""
    nucleotides = ['A', 'T', 'G', 'C']
    # YOUR CODE HERE
    pass

# Test
seq = "ATGCATGC"
counts = count_dinucleotides(seq)
print_dinucleotide_table(counts)

# %% [markdown]
# ## 🧬 Problem 7: Codon Usage Bias
#
# Calculate the codon usage frequency for each amino acid.
# This is important for understanding gene expression optimization.
#
# ```
# Example:
# For sequence "TTTTCCCTC", the codons are TTT, TCC, CTC
# - Phe (F): TTT=1 (100% usage of TTT vs TTC)
# - Ser (S): TCC=1 (TCC usage out of all Ser codons)
# - Leu (L): CTC=1 (CTC usage out of all Leu codons)
# ```

# %%
from collections import defaultdict

def calculate_codon_usage(sequence, codon_table):
    """
    Calculate codon usage statistics.
    
    Args:
        sequence: DNA sequence
        codon_table: dict mapping codons to amino acids
        
    Returns:
        Dictionary: {amino_acid: {codon: count}}
    """
    # YOUR CODE HERE
    pass

# Test with a sample sequence
test_seq = "ATGTTTTCCCTCGCGAAATGA"
usage = calculate_codon_usage(test_seq, CODON_TABLE)
print(usage)

# %% [markdown]
# ## 🧬 Problem 8: FASTA Parser with Dictionary
#
# Parse a FASTA-formatted string into a dictionary.
#
# ```
# Input:
# >seq1
# ATGC
# >seq2
# GCTA
#
# Output:
# {'seq1': 'ATGC', 'seq2': 'GCTA'}
# ```

# %%
def parse_fasta_string(fasta_text):
    """
    Parse FASTA-formatted string to dictionary.
    
    Args:
        fasta_text: string with FASTA content
        
    Returns:
        Dictionary mapping sequence IDs to sequences
    """
    # YOUR CODE HERE
    pass

# Test
fasta = """>gene1 Human insulin
ATGGCCCTG
TGGATGCGA
>gene2 Mouse hemoglobin
ATGGTGCAC
"""

sequences = parse_fasta_string(fasta)
print(sequences)

# %% [markdown]
# ## 🧬 Problem 9: Find Shared K-mers
#
# Find all k-mers that are shared between two sequences.
# Return positions in both sequences.
#
# ```
# Example:
# seq1 = "ATGCATGC"
# seq2 = "GCATGCAT"
# k = 4
#
# Shared 4-mers:
# ATGC: seq1 pos [0,4], seq2 pos [2]
# GCAT: seq1 pos [2], seq2 pos [0,4]
# CATG: seq1 pos [3], seq2 pos [1,5]
# TGCA: seq1 pos [1], seq2 pos [3]
# ```

# %%
def find_shared_kmers(seq1, seq2, k):
    """
    Find k-mers shared between two sequences.
    
    Returns:
        Dictionary: {kmer: {'seq1': [positions], 'seq2': [positions]}}
    """
    # YOUR CODE HERE
    pass

# Test
result = find_shared_kmers("ATGCATGC", "GCATGCAT", 4)
for kmer, positions in result.items():
    print(f"{kmer}: {positions}")

# %% [markdown]
# ## 🧬 Problem 10: Gene Expression Matrix
#
# Create a dictionary-based representation of a gene expression matrix.
# Implement functions to:
# 1. Find highly expressed genes (expression > threshold)
# 2. Find genes differentially expressed between samples
#
# ```
# Example data:
# expression = {
#     'GeneA': {'Sample1': 100, 'Sample2': 50},
#     'GeneB': {'Sample1': 20, 'Sample2': 200},
#     'GeneC': {'Sample1': 5, 'Sample2': 5}
# }
# ```

# %%
def highly_expressed_genes(expression_data, sample, threshold):
    """
    Find genes with expression above threshold in a specific sample.
    Use comprehension.
    
    Returns:
        List of (gene_name, expression_value) tuples
    """
    # YOUR CODE HERE
    pass

def differential_genes(expression_data, sample1, sample2, fold_change=2):
    """
    Find genes with >= fold_change difference between samples.
    
    Returns:
        Dictionary: {gene: {'ratio': fold_change, 'higher_in': sample_name}}
    """
    # YOUR CODE HERE
    pass

# Test
expr = {
    'GeneA': {'Sample1': 100, 'Sample2': 50},
    'GeneB': {'Sample1': 20, 'Sample2': 200},
    'GeneC': {'Sample1': 5, 'Sample2': 5}
}

print("Highly expressed in Sample1:")
print(highly_expressed_genes(expr, 'Sample1', 50))

print("\nDifferentially expressed (2-fold):")
print(differential_genes(expr, 'Sample1', 'Sample2', 2))

# %% [markdown]
# ---
#
# ## 📚 Summary
#
# In this assignment, you practiced:
#
# 1. **Lists & Tuples**: Codon extraction, sequence slicing
# 2. **Dictionaries**: Genetic code, k-mer counting, expression data
# 3. **Sets**: Comparing protein/sequence sets
# 4. **Comprehensions**: Filtering, transforming, building data structures
# 5. **Real applications**: Translation, codon usage, differential expression
#
# These data structures are fundamental to bioinformatics programming!
#
# ---
