# %% [markdown]
# # Assignment: 02 Basic Algorithms
#
# Based on course notebook: `Course/Tier_4_Algorithms_and_Data_Structures/01_Complexity_Analysis/02_basic_algorithms.ipynb`
#
# **Navigation:** [Course topic](/`Course/Tier_4_Algorithms_and_Data_Structures/01_Complexity_Analysis/02_basic_algorithms.ipynb`) · [Solution](/`Solutions/Course_Topics/Tier_4_Algorithms_and_Data_Structures/01_Complexity_Analysis/02_basic_algorithms.ipynb`)

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
