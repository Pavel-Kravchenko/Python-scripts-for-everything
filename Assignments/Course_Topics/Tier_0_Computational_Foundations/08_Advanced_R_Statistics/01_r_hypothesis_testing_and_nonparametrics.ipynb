# %% [markdown]
# # Assignment: 01 R Hypothesis Testing And Nonparametrics
#
# Based on course notebook: `Course/Tier_0_Computational_Foundations/08_Advanced_R_Statistics/01_r_hypothesis_testing_and_nonparametrics.ipynb`
#
# **Navigation:** [Course topic](/`Course/Tier_0_Computational_Foundations/08_Advanced_R_Statistics/01_r_hypothesis_testing_and_nonparametrics.ipynb`) · [Solution](/`Solutions/Course_Topics/Tier_0_Computational_Foundations/08_Advanced_R_Statistics/01_r_hypothesis_testing_and_nonparametrics.ipynb`)

# %% [markdown]
# ## Complicated moments explained
# These are common points where learners usually get stuck:
# - Difference between command syntax and conceptual model (what changes state vs what only inspects).
# - Interpreting statistical output: p-value alone is not enough without effect size and assumptions.
# - Reproducibility: the same command can yield different outputs if input files or working directory differ.

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
