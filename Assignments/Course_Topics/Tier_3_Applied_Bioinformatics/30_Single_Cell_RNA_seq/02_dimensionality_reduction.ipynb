# %% [markdown]
# # Assignment: scRNA-seq: Dimensionality Reduction and Clustering
#
# Based on course notebook: `Course/Tier_3_Applied_Bioinformatics/30_Single_Cell_RNA_seq/02_dimensionality_reduction.ipynb`
#
# **Navigation:** [Course topic](/Course/Tier_3_Applied_Bioinformatics/30_Single_Cell_RNA_seq/02_dimensionality_reduction.ipynb)

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
