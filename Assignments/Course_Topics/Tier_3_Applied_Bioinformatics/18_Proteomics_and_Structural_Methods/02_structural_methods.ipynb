# %% [markdown]
# # Assignment: 02 Structural Methods
#
# Based on course notebook: `Course/Tier_3_Applied_Bioinformatics/18_Proteomics_and_Structural_Methods/02_structural_methods.ipynb`
#
# **Navigation:** [Course topic](/`Course/Tier_3_Applied_Bioinformatics/18_Proteomics_and_Structural_Methods/02_structural_methods.ipynb`) · [Solution](/`Solutions/Course_Topics/Tier_3_Applied_Bioinformatics/18_Proteomics_and_Structural_Methods/02_structural_methods.ipynb`)

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
