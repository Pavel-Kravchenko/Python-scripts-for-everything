# %% [markdown]
# # Assignment: 01 Genome Assembly And Advanced Ngs
#
# Based on course notebook: `Course/Tier_3_Applied_Bioinformatics/17_Genome_Assembly_and_Advanced_NGS/01_genome_assembly_and_advanced_ngs.ipynb`
#
# **Navigation:** [Course topic](/`Course/Tier_3_Applied_Bioinformatics/17_Genome_Assembly_and_Advanced_NGS/01_genome_assembly_and_advanced_ngs.ipynb`) · [Solution](/`Solutions/Course_Topics/Tier_3_Applied_Bioinformatics/17_Genome_Assembly_and_Advanced_NGS/01_genome_assembly_and_advanced_ngs.ipynb`)

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
