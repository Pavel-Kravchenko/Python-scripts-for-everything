# %% [markdown]
# # Assignment: miRNA-seq Processing and Analysis
#
# Based on course notebook: `Course/Tier_3_Applied_Bioinformatics/35_Small_RNA_and_ncRNA/01_mirna_seq_pipeline.ipynb`
#
# **Navigation:** [Course topic](/Course/Tier_3_Applied_Bioinformatics/35_Small_RNA_and_ncRNA/01_mirna_seq_pipeline.ipynb)

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
