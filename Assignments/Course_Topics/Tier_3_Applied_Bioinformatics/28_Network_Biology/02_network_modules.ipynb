# %% [markdown]
# # Assignment: 02 Network Modules
#
# Based on course notebook: `Course/Tier_3_Applied_Bioinformatics/28_Network_Biology/02_network_modules.ipynb`
#
# **Navigation:** [Course topic](/`Course/Tier_3_Applied_Bioinformatics/28_Network_Biology/02_network_modules.ipynb`) · [Solution](/`Solutions/Course_Topics/Tier_3_Applied_Bioinformatics/28_Network_Biology/02_network_modules.ipynb`)

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
