# %% [markdown]
# # Assignment: 01 Strings And Sequences
#
# Based on course notebook: `Course/Tier_1_Python_for_Bioinformatics/04_Strings_and_Sequences/01_strings_and_sequences.ipynb`
#
# **Navigation:** [Course topic](/`Course/Tier_1_Python_for_Bioinformatics/04_Strings_and_Sequences/01_strings_and_sequences.ipynb`) · [Solution](/`Solutions/Course_Topics/Tier_1_Python_for_Bioinformatics/04_Strings_and_Sequences/01_strings_and_sequences.ipynb`)

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
