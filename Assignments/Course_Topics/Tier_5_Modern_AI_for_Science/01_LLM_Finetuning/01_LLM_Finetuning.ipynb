# %% [markdown]
# # Assignment: 01 Llm Finetuning
#
# Based on course notebook: `Course/Tier_5_Modern_AI_for_Science/01_LLM_Finetuning/01_LLM_Finetuning.ipynb`
#
# **Navigation:** [Course topic](/`Course/Tier_5_Modern_AI_for_Science/01_LLM_Finetuning/01_LLM_Finetuning.ipynb`) · [Solution](/`Solutions/Course_Topics/Tier_5_Modern_AI_for_Science/01_LLM_Finetuning/01_LLM_Finetuning.ipynb`)

# %% [markdown]
# ## Complicated moments explained
# These are common points where learners usually get stuck:
# - Model score != biological truth. Treat predictions as ranked hypotheses requiring validation.
# - Context length and tokenization can change model behavior more than minor hyperparameter tweaks.
# - Domain shift is common: performance on curated benchmarks may not transfer to your assay/data source.

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
