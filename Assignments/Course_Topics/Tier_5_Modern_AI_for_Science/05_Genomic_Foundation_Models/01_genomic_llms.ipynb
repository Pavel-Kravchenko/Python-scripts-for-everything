# %% [markdown]
# # Assignment: Genomic Foundation Models: Nucleotide Transformers, HyenaDNA, and Evo
#
# Based on course notebook: `Course/Tier_5_Modern_AI_for_Science/05_Genomic_Foundation_Models/01_genomic_llms.ipynb`
#
# **Navigation:** [Course topic](/Course/Tier_5_Modern_AI_for_Science/05_Genomic_Foundation_Models/01_genomic_llms.ipynb)

# %% [markdown]
# ## Tasks
#
# 1. Summarize the core concept in 3–5 bullet points.
# 2. Reproduce one main method from the course notebook using your own inputs.
# 3. Run one extension experiment and report what changed.
# 4. Document assumptions, edge cases, and limitations.

# %%
# Write your solution here
