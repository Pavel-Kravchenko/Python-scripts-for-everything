# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import altair as alt
from Bio import SeqIO
from Bio.SeqUtils import GC
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
record_dict = SeqIO.to_dict(SeqIO.parse("/home/pavel/Desktop/Work/Species/Saccharomyces/genomes mito/YJM326.fasta", "fasta"))
print(record_dict)

name = list(record_dict.keys())[0]
#print(name)
sequence = record_dict[name].seq
#print(seq)
# Out:
# {'CP006482.2': SeqRecord(seq=Seq('TTCATAATTAATTTTTTATATATATATTATATTATAATATTAATTTATATTATA...ATA', SingleLetterAlphabet()), id='CP006482.2', name='CP006482.2', description='CP006482.2 Saccharomyces cerevisiae YJM326 mitochondrion, complete genome', dbxrefs=[])}

# %%
/home/pavel/Desktop/Python/test_work/511145_2.fasta

# %%
ecnt = {}
seq = ""
with open("/home/pavel/Desktop/Work/Species/Saccharomyces/genomes mito/YJM326.fasta", "r") as seq_data:
    c = 0
    for line in seq_data:
        if c == 0:
            c += 1
            continue
        if c == 1:
            seq += line.strip()
for i in range(len(seq)-1):
    dinuc = seq[i:i+2]
    if dinuc in ecnt:
        ecnt[dinuc] += 1
    else:
        ecnt[dinuc] = 1
print(ecnt)
# Out:
# {'TT': 13568, 'TC': 2344, 'CA': 1795, 'AT': 19310, 'TA': 19402, 'AA': 14811, 'CT': 2272, 'CC': 1971, 'CG': 1015, 'GG': 2299, 'GT': 2257, 'GC': 842, 'TG': 2094, 'GA': 2653, 'AG': 2643, 'AC': 1896}

# %%
df = pd.DataFrame([ecnt])
print(df)
# Out:
#       AA    AC    AG     AT    CA    CC    CG    CT    GA   GC    GG    GT  \
# 0  14811  1896  2643  19310  1795  1971  1015  2272  2653  842  2299  2257
#
#       TA    TC    TG     TT
# 0  19402  2344  2094  13568

# %%
s = pd.Series(ecnt)
print(s)
df = s.to_frame(name=None)
print(df)

# %%
height, width = 16, 16
sns.set(rc={"figure.figsize": (width, height)})

sns.set()
sns.set_style("whitegrid", {'grid.linestyle': '--'})
sns.set_context("paper", 1.5, {"lines.linewidth": 4})
sns.set_palette("winter_r", 8, 1)
sns.set('talk', 'whitegrid', 'dark', font_scale=1.5,
        rc={"lines.linewidth": 2, 'grid.linestyle': '--'})

# %%
sns.boxplot(data=df)

plt.ylabel("Count", size=15)
plt.xticks(size=15)
plt.yticks(size=15)
# Out:
# (array([-2500.,     0.,  2500.,  5000.,  7500., 10000., 12500., 15000.,
#         17500., 20000., 22500.]), <a list of 11 Text yticklabel objects>)
